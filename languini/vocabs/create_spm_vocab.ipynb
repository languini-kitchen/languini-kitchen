# %%
import os
import numpy as np
import sentencepiece as spm

from tqdm import tqdm

# %%
# !pwd
# Out:
# /home/imanol/languini-kitchen/languini/vocabs

# %%
BOOKS3 = "../../data/books3"
DATA_PATH = "../../data/books"

# %%
train_files = np.load(os.path.join(DATA_PATH, "file_list_train.npy"))[:10,0]
train_files.shape
# Out:
# (10,)

# %%
names = [os.path.splitext(os.path.basename(fn))[0] for fn in train_files]
names[:5]
# Out:
# ['Roots, Radicals and Rockers - Billy Bragg.epub',
#  'A History of the World Cup_ 1930-2014 - Clemente A. Lisi (retail).epub',
#  'Gently Where She Lay - Alan Hunter.epub',
#  'The Weirdness - Jeremy P. Bushnell.epub',
#  'Dog Dish of Doom--An Agent to the Paws Mys - E.J. Copperman.epub']

# %%
def get_books3_file_paths(books3_dir, file_names):
    """
    Walks through the raw books3 folder and checks if the filenames exist.

    Args:
        books3_dir (str): Path to the books3 root folder.
        file_names (list): List of the file names.

    Raises>
        ValueError: If a file name is not found.
    """
    all_files = {}
    for root, dirs, files in tqdm(list(os.walk(books3_dir))):
        for file_name in files:
            all_files[os.path.splitext(file_name)[0]] = os.path.join(root, file_name)
    
    books3_paths = []
    for fn in file_names:
        if not fn in all_files.keys():
            raise ValueError(f"Filename {fn} not found when walking through {books3_dir}")
        else:
            books3_paths.append(all_files[fn])
    
    return list(books3_paths)

# %%
book3_paths = get_books3_file_paths(BOOKS3, names)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 53.25it/s]

# %%
def get_contents(file_absolute_paths):   
    contents = []
    for filename in file_absolute_paths:
        with open(filename, "rb") as f:
            content = f.read()
        # replace all the \r\n with \n 
        content = content.replace(b"\r\n", b"\n")
        # trim the text to remove empty space at the beginning and end
        content = content.strip()

        contents.append(content)
    print(f"Loaded {len(contents)} files!")
    return contents

# %%
contents = get_contents(book3_paths)
# Out:
# Loaded 10 files!

# %%
NEW_DOC_TOKEN = b"<D>"
concat_contents = NEW_DOC_TOKEN + NEW_DOC_TOKEN.join(contents)

# %%
print(f"Total size of the contents that will be used for vocab generation is {len(concat_contents):,} bytes.")
# Out:
# Total size of the contents that will be used for vocab generation is 6,309,760 bytes.

# %%
# Save the concatenated contents to a file
TMP_FILENAME = ".tmp_concat_books3.txt"
if os.path.exists(TMP_FILENAME):
    os.remove(TMP_FILENAME)
with open(TMP_FILENAME, 'wb') as f:
    f.write(concat_contents)

# %%
# this will take a while for large vocabs
spm.SentencePieceTrainer.Train(
    f" --input={TMP_FILENAME}" +
    f" --model_prefix=spm_models/test_2048" +
    f" --model_type=bpe" +
    f" --vocab_size=2048" +
    " --hard_vocab_limit=True" +
    " --input_sentence_size=2000000" +
    " --unk_id=1" + 
    " --bos_id=-1" +
    " --eos_id=-1" +
    " --pad_id=0" +
    " --max_sentencepiece_length=99" +
    " --split_by_unicode_script=True" +  
    " --split_by_number=True" +
    " --split_by_whitespace=True" +
    " --add_dummy_prefix=False" + 
    " --byte_fallback=True" +
    " --remove_extra_whitespaces=False" +
    " --allow_whitespace_only_pieces=True" +
    " --normalization_rule_name=identity" +
    " --user_defined_symbols=<D>" +
    " --split_digits=True" +
    " --vocabulary_output_piece_score=False"
)
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command:  --input=.tmp_concat_books3.txt --model_prefix=spm_models/test_2048 --model_type=bpe --vocab_size=2048 --hard_vocab_limit=True --input_sentence_size=2000000 --unk_id=1 --bos_id=-1 --eos_id=-1 --pad_id=0 --max_sentencepiece_length=99 --split_by_unicode_script=True --split_by_number=True --split_by_whitespace=True --add_dummy_prefix=False --byte_fallback=True --remove_extra_whitespaces=False --allow_whitespace_only_pieces=True --normalization_rule_name=identity --user_defined_symbols=<D> --split_digits=True --vocabulary_output_piece_score=False
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: .tmp_concat_books3.txt
#   input_format:
#   model_prefix: spm_models/test_2048
#   model_type: BPE
#   vocab_size: 2048
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 2000000
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 99
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 1
#   user_defined_symbols: <D>
#   required_chars:
#   byte_fallback: 1
#   vocabulary_output_piece_score: 0
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: -1
#   eos_id: -1
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_diffe

# %%
# Lossless Test of the generated SentencePiece model vocab
sp = spm.SentencePieceProcessor()
spm_model_path = f'spm_models/test_2048.model'
print(f'Loading {spm_model_path} spm file...')
sp.Load(spm_model_path)

# this takes a few minutes ...
res = []
sample_contents = contents[:1_000]  # Sample only some contents s.t. this doesn't take forever
print(f"Testing lossless reconstruction of {len(sample_contents)} documents...")
for x in tqdm(sample_contents):
    enc_x = sp.Encode(x)
    dec_enc_x = bytes(sp.Decode(enc_x), 'utf-8')
    res.append(x == dec_enc_x)

# True if all docs were successfully reconstructed
if all(res):
    print(f"All docs were successfully reconstructed!")
else:
    print(f"WARNING: Some docs were not successfully reconstructed!")
    print(f'Number of docs that were not successfully reconstructed: {len([x for x in res if not x])}')
# Out:
# rential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: identity
#   add_dummy_prefix: 0
#   remove_extra_whitespaces: 0
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: .tmp_concat_books3.txt
# trainer_interface.cc(378) LOG(WARNING) Found too long line (4530 > 4192).
# trainer_interface.cc(380) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(381) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(407) LOG(INFO) Loaded all 34832 sentences
# trainer_interface.cc(414) LOG(INFO) Skipped 1 too long sentences.
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x00>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x01>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x02>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x03>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x04>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x05>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x06>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x07>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x08>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x09>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x0A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x0B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x0C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x0D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x0E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x0F>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x10>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x11>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x12>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x13>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x14>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x15>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x16>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x17>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x18>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x19>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x1A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x1B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x1C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x1D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x1E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x1F>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x20>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x21>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x22>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x23>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x24>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x25>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x26>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x27>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x28>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x29>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x2A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x2B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x2C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x2D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x2E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x2F>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x30>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x31>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x32>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x33>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x34>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x35>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x36>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x37>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x38>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x39>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x3A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x3B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x3C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x3D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x3E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x3F>
# trainer_
# Loading spm_models/test_2048.model spm file...
# Testing lossless reconstruction of 10 documents...
# interface.cc(423) LOG(INFO) Adding meta_piece: <0x40>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x41>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x42>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x43>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x44>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x45>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x46>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x47>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x48>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x49>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x4A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x4B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x4C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x4D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x4E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x4F>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x50>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x51>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x52>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x53>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x54>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x55>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x56>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x57>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x58>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x59>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x5A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x5B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x5C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x5D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x5E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x5F>
#   0%|                                                                                                                                                                                                                                                                               | 0/10 [00:00<?, ?it/s]) LOG(INFO) Adding meta_piece: <0x60>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x61>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x62>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x63>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x64>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x65>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x66>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x67>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x68>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x69>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x6A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x6B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x6C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x6D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x6E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x6F>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x70>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x71>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x72>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x73>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x74>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x75>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x76>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x77>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x78>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x79>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x7A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x7B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x7C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x7D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x7E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x7F>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x80>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x81>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x82>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x83>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x84>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x85>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x86>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x87>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x88>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x89>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x8A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x8B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x8C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x8D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x8E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x8F>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x90>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x91>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x92>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x93>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x94>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x95>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x96>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x97>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x98>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x99>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x9A>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x9B>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x9C>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x9D>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x9E>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0x9F>
#  10%|██████████████████████████▎                                                                                                                                                                                                                                            | 1/10 [00:00<00:07,  1.17it/s]0xA0>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA1>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA2>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA3>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA4>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA5>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA6>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA7>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA8>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xA9>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xAA>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xAB>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xAC>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xAD>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xAE>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xAF>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB0>
#  20%|████████████████████████████████████████████████████▌                                                                                                                                                                                                                  | 2/10 [00:02<00:08,  1.06s/it]ainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB1>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB2>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB3>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB4>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB5>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB6>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB7>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB8>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xB9>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xBA>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xBB>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xBC>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xBD>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xBE>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xBF>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC0>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC1>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC2>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC3>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC4>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC5>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC6>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC7>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC8>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xC9>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xCA>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xCB>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xCC>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xCD>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xCE>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xCF>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD0>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD1>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD2>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD3>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD4>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD5>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD6>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD7>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD8>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xD9>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xDA>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xDB>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xDC>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xDD>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xDE>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xDF>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE0>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE1>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE2>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE3>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE4>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE5>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE6>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE7>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE8>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xE9>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xEA>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xEB>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xEC>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xED>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xEE>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xEF>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF0>
#  30%|██████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                                                        | 3/10 [00:02<00:05,  1.37it/s]) Adding meta_piece: <0xF1>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF2>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF3>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF4>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF5>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF6>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF7>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF8>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xF9>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xFA>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xFB>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xFC>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xFD>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xFE>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <0xFF>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=6225379
# trainer_interface.cc(548) LOG(INFO) Done: 99.9516% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=80
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999516
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 34832 sentences.
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 34832
# trainer_interface.cc(608) LOG(INFO) Done! 100769
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=148946 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35915 size=20 all=2575 active=1857 piece=ing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18694 size=40 all=3698 active=2980 piece=ll
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13156 size=60 all=5185 active=4467 piece=▁be
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9743 size=80 all=6310 active=5592 piece=se
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7164 size=100 all=7153 active=6435 piece=▁an
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7037 min_freq=587
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5625 size=120 all=8408 active=2235 piece=us
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4750 size=140 all=9591 active=3418 piece=ag
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4185 size=160 all=10701 active=4528 piece=ight
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3619 size=180 all=11642 active=5469 piece=ist
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3395 size=200 all=12782 active=6609 piece=▁te
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3391 min_freq=519
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3051 size=220 all=13706 active=1909 piece=▁or
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2753 size=240 all=14485 active=2688 piece=ide
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2470 size=260 all=15242 active=3445 piece=▁she
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2275 size=280 all=16337 active=4540 piece=���like
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2061 size=300 all=17117 active=5320 piece=▁U
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2034 min_freq=441
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1913 size=320 all=17695 active=1545 piece=are
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1796 size=340 all=18824 active=2674 piece=▁first
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1648 size=360 all=19463 active=3313 piece=▁says
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1570 size=380 all=20041 active=3891 piece=ff
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1490 size=400 all=21014 active=4864 piece=ft
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1490 min_freq=372
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1396 size=420 all=21730 active=1732 piece=other
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1299 size=440 all=22282 active=2284 piece=▁app
#  40%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                                             | 4/10 [00:02<00:03,  1.58it/s] size=460 all=22782 active=2784 piece=ings
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1157 size=480 all=23408 active=3410 piece=ought
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1090 size=500 all=23843 active=3845 piece=▁sm
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1077 min_freq=300
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1037 size=520 all=24148 active=1475 piece=ne
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=992 size=540 all=24536 active=1863 piece=▁going
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=934 size=560 all=24904 active=2231 piece=cl
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=896 size=580 all=25551 active=2878 piece=▁minute
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=859 size=600 all=26164 active=3491 piece=▁Un
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=858 min_freq=255
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=826 size=620 all=26439 active=1562 piece=ife
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=792 size=640 all=26918 active=2041 piece=ons
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=762 size=660 all=27261 active=2384 piece=▁these
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=733 size=680 all=27631 active=2754 piece=We
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=720 size=700 all=28026 active=3149 piece=▁four
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=720 min_freq=224
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=699 size=720 all=28371 active=1743 piece=ert
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=671 size=740 all=28726 active=2098 piece=ody
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=649 size=760 all=29091 active=2463 piece=▁seem
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=625 size=780 all=29610 active=2982 piece=▁tournam
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=603 size=800 all=29880 active=3252 piece=▁ra
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=602 min_freq=199
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=583 size=820 all=30170 active=1760 piece=▁ed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=568 size=840 all=30452 active=2042 piece=▁though
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=546 size=860 all=30654 active=2244 piece=**
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=537 size=880 all=30896 active=2486 piece=She
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=521 size=900 all=31294 active=2884 piece=▁wal
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=521 min_freq=180
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=508 size=920 all=31727 active=1992 piece=ret
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=494 size=940 all=32108 active=2373 piece=▁light
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=482 size=960 all=32425 active=2690 piece=osed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=466 size=980 all=32719 active=2984 piece=▁resp
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=455 size=1000 all=33110 active=3375 piece=▁moment
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=454 min_freq=162
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=442 size=1020 all=33365 active=1906 piece=▁pull
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=435 size=1040 all=33653 active=2194 piece=atter
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=429 size=1060 all=33923 active=2464 piece=▁felt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=422 size=1080 all=34240 active=2781 piece=ention
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=412 size=1100 all=34533 active=3074 piece=▁next
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=412 min_freq=147
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=403 size=1120 all=34635 active=1829 piece=▁different
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=394 size=1140 all=34789 active=1983 piece=▁question
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=385 size=1160 all=35122 active=2316 piece=ump
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=374 size=1180 all=35360 active=2554 piece=▁mid
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=365 size=1200 all=35478 active=2672 piece=br
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=365 min_freq=135
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=359 size=1220 all=35859 active=2105 piece=▁sign
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=353 size=1240 all=36155 active=2401 piece=▁doesn
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=345 size=1260 all=36337 active=2583 piece=Bri
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=337 size=1280 all=36600 active=2846 piece=ev
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=330 size=1300 all=36845 active=3091 piece=▁gun
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=330 min_freq=124
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=323 size=1320 all=37049 active=2038 piece=▁Af
#  50%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                   | 5/10 [00:03<00:02,  1.73it/s]freq=320 size=1340 all=37285 active=2274 piece=▁contin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=314 size=1360 all=37497 active=2486 piece=though
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=308 size=1380 all=37705 active=2694 piece=▁interest
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=300 size=1400 all=38106 active=3095 piece=▁vis
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=300 min_freq=115
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=296 size=1420 all=38271 active=2057 piece=uff
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=290 size=1440 all=38486 active=2272 piece=▁US
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=286 size=1460 all=38732 active=2518 piece=▁Ken
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=280 size=1480 all=38837 active=2623 piece=▁net
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=275 size=1500 all=38986 active=2772 piece=ienc
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=274 min_freq=108
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=271 size=1520 all=39119 active=2069 piece=If
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=268 size=1540 all=39305 active=2255 piece=▁Americans
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=264 size=1560 all=39515 active=2465 piece=▁FIFA
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=261 size=1580 all=39799 active=2749 piece=▁less
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=258 size=1600 all=39986 active=2936 piece=▁conversation
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=257 min_freq=102
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=254 size=1620 all=40164 active=2178 piece=iec
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=251 size=1640 all=40409 active=2423 piece=▁crowd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=246 size=1660 all=40555 active=2569 piece=▁times
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=241 size=1680 all=40686 active=2700 piece=▁feeling
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=238 size=1700 all=40892 active=2906 piece=▁white
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=238 min_freq=96
# trainer_interface.cc(686) LOG(INFO) Saving model: spm_models/test_2048.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: spm_models/test_2048.vocab
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.44it/s]
# All docs were successfully reconstructed!

# %%
os.remove(TMP_FILENAME)
